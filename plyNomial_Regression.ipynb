# %% [markdown]
# <a href="https://colab.research.google.com/github/mollah2022/Neural-Network/blob/main/plyNomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/linear_data.csv")
df1.head()
# Out:
#          x         y
# 0  0.00000  4.447692
# 1  0.02004  5.024612
# 2  0.04008  5.869593
# 3  0.06012  4.722490
# 4  0.08016  4.877101

# %%
x_linear = df1[['x']]
y_linear = df1[['y']]

# %%
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nonlinear_data.csv")
df2.head()
# Out:
#          x         y
# 0  0.00000 -0.155043
# 1  0.02004  0.081809
# 2  0.04008 -0.014298
# 3  0.06012  0.143978
# 4  0.08016  0.019553

# %%
x_nonLinear = df2[['x']]
y_nonLinear = df2[['y']]

# %%
#linear
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.scatter(x_linear, y_linear, color='blue', label='Data with Linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Relationship')
plt.legend()

#non-linear
plt.subplot(1, 2, 2)
plt.scatter(x_nonLinear, y_nonLinear, color='green', label='Data with Non-linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()

plt.tight_layout()
plt.show()

# %%
df1.corr()
# Out:
#          x        y
# x  1.00000  0.99644
# y  0.99644  1.00000

# %%
df2.corr()
# Out:
#           x         y
# x  1.000000 -0.065736
# y -0.065736  1.000000

# %%
from sklearn.linear_model import LinearRegression

# %%
reg1 = LinearRegression()

# %%
reg1.fit(x_linear, y_linear) # x= x_linear.reshape(-1, 1)
# Out:
# LinearRegression()

# %%
reg1.score(x_linear , y_linear)
# Out:
# 0.9928923730526016

# %%
plt.scatter(x_linear, y_linear, color='blue', label='Data with Linear Relationship')
plt.plot(x_linear, reg1.predict(x_linear), color='red', label='Best fit line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Relationship')
plt.legend()

# %%
reg2 = LinearRegression()

# %%
reg2.fit(x_nonLinear , y_nonLinear)
# Out:
# LinearRegression()

# %%
reg2.score(x_nonLinear, y_nonLinear)
# Out:
# 0.004321199719043656

# %%
plt.scatter(x_nonLinear, y_nonLinear, color='green', label='Data with Non-linear Relationship')
plt.plot(x_nonLinear, reg2.predict(x_nonLinear), color='red', label='Best fit line')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=6) # polynomial regression with degree 2
X_poly = poly.fit_transform(x_nonLinear)

# %%
X_poly.shape
# Out:
# (500, 7)

# %%
reg_poly = LinearRegression()

# %%
reg_poly.fit(X_poly, y_nonLinear)
# Out:
# LinearRegression()

# %%
reg_poly.score(X_poly, y_nonLinear)
# Out:
# 0.993062484449735

# %%
plt.scatter(x_nonLinear, y_nonLinear, color='green', label='Data with Non-linear Relationship')
plt.plot(x_nonLinear, 2 * np.sin(x_nonLinear), color='orange', label='True Non-linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Non-linear Relationship')
plt.legend()

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_poly,y_nonLinear, test_size=.30, random_state=1 )

# %%
reg = LinearRegression()

# %%
reg.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
reg.score(xtest, ytest)
# Out:
# 0.9905664282631418

# %%
reg.score(xtrain, ytrain)
# Out:
# 0.9939293669434809
